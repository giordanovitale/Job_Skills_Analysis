# %%
# Data manipulation
import pandas as pd
import numpy as np
import helpers as hp

# Viz
import matplotlib.pyplot as plt
import seaborn as sns

# Dev
import importlib
importlib.reload(hp)

# Display
sns.set_style("whitegrid")
pd.options.display.max_columns = 200
pd.options.display.max_rows = 200

# %% [markdown]
# ## Clean all data

# %%
hp.clean_all()

# %% [markdown]
# ## Load cleaned data

# %%
orgs = hp.read_feather("data/cleaned/organizations.feather")
cand = hp.read_feather("data/cleaned/candidates.feather")
jobs = hp.read_feather("data/cleaned/jobs.feather")
apps = hp.read_feather("data/cleaned/applications.feather")
hist = hp.read_feather("data/cleaned/histories.feather")

# %% [markdown]
# ## Preview data

# %% [markdown]
# Organizations

# %%
orgs.head(1)
# Out:
#                org_id        org_name org_industry org_type org_country  \
# 0  001b00000047HAQAA2  Candidate Pool   Technology      NaN       ITALY
#
#   org_city
# 0    MILAN

# %% [markdown]
# Candidates

# %%
cands.head(1)
# Out:
#               cand_id                                           cand_edu  \
# 0  0036700003YdjftAAB  Bocconi University   Milan  IT    Master of Sc...
#
#                                          cand_skills  \
# 0  BUSINESS INTELLIGENCE;BUSINESS INTELLIGENCE;MI...
#
#                                       cand_it_skills cand_general_skills  \
# 0  ETL;PLATFORM AS A SERVICE;AMAZON WEB SERVICES;...                 NaN
#
#                                    cand_other_skills cand_current_title  \
# 0  ENGLISH;ITALIAN;FRENCH;GERMAN;JAPANESE;RUSSIAN...        REMOTE WORK
#
#               cand_current_employer  \
# 0  BUSINESS INTELLIGENCE CONSULTING
#
#                                     cand_prev_titles  \
# 0  DATA PRODUCT LEAD;HEAD OF BUSINESS INTELLIGENC...
#
#                                  cand_prev_employers  \
# 0  SHOPFULLY INTERNATIONAL GROUP;DAWANDA GMBH.;BU...
#
#                                         cand_summary           cand_shortlist  \
# ...

# %% [markdown]
# Jobs

# %%
jobs.head(1)
# Out:
#                job_id                    job_title  \
# 0  a0Fb0000003SB4AEAW  ANALYST PROGRAMMER BIG DATA
#
#                                      job_description job_category   job_term  \
# 0  Una societa? di  System Interation , nostra cl...   CONSULTING  Permanent
#
#   job_contract  job_n_positions      job_reason job_experience  \
# 0    Permanent              3.0  Increase in HC    04-06 years
#
#                                           job_skills job_team_lead_size  \
# 0  BIG DATA;HADOOP;HIVE;HBASE;DIGITAL INTELLIGENC...                3-5
#
#   job_project_management job_pct_travel job_lang_1 job_lang_2  \
# 0                    Yes           100%    English    Italian
#
#   job_lang_1_level job_lang_2_level  job_salary  job_bonus  \
# 0       Basic User       Basic User     55000.0        0.0
#
#                   job_benefit job_locations  job_osn_practice  job_fee  \
# 0  MEAL COUPONS;MOBILE;LAPTOP         MILAN  DATA ENGINEERING     20.0
#
# ...

# %% [markdown]
# Job applications

# %%
apps.head(1)
# Out:
#                app_id              org_id             cand_id  \
# 0  a0Db000000VHhmrEAD  001b0000009VWc1AAG  003b0000013RrinAAC
#
#                job_id   app_job_title  \
# 0  a0Fb000000EGSTkEAP  DATA SCIENTIST
#
#                                               app_cv app_current_role  \
# 0  2      Federica Membretti      +39 340 81 95 9...              NaN
#
#   app_contract   app_city app_reject_qualifier                  app_stage  \
# 0         Perm  VIMODRONE    DECLINED POSITION  Sent to client - Withdraw
#
#        app_created_at app_cv_received_at
# 0 2015-11-17 14:00:20         2016-02-18

# %% [markdown]
# Employment histories

# %%
hist.head(1)
# Out:
#               hist_id             cand_id  \
# 0  a0Ab0000001nDaTEAU  003b0000006JthTAAS
#
#                                     hist_description hist_org hist_start_at  \
# 0  Create relationships with Enterprise & Emergin...      SAP    2009-08-01
#
#   hist_end_at     hist_created_at  hist_years
# 0         NaT 2013-06-03 22:45:30         3.8
